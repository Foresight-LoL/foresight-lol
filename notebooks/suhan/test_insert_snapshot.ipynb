# %%
import math
import os
import time 
import re
import requests
import polars as pl

from decorator import append
from dotenv import load_dotenv
from duckdb.experimental.spark.sql.functions import length
from datetime import datetime

load_dotenv(override=True)

RIOT_PERSONAL_API_KEY = os.getenv("LOL_PERSONAL_API_KEY")
POSTGRES_LOCAL_URL = os.getenv("POSTGRES_LOCAL_URL")

# %%
_camel_case_regex = re.compile(
    r"(?<=[a-z])(?=[A-Z])"  # camelCase: survive|Min
    r"|(?<=[A-Z])(?=[A-Z][a-z])"  # acronym: HTML|Parser
    r"|(?<=[a-zA-Z])(?=\d)"  # letter→digit: survive|15
    r"|(?<=\d)(?=[a-zA-Z])"  # digit→letter: 15|min
)


def camel_to_snake(input_str: str) -> str:
    return _camel_case_regex.sub("_", input_str).lower()


def snake_all_keys(json_obj: dict):
    if isinstance(json_obj, dict):
        return {camel_to_snake(key): snake_all_keys(value) for key, value in json_obj.items()}

    if isinstance(json_obj, list):
        return [snake_all_keys(value) for value in json_obj]

    return json_obj

# %%
players = pl.read_database_uri("SELECT * FROM players", POSTGRES_LOCAL_URL)
players
# Out:
# shape: (3_100, 5)
# ┌──────────────────────────────┬──────────────────┬──────────┬────────┬────────────────────────────┐
# │ puuid                        ┆ game_name        ┆ tag_line ┆ region ┆ synced_at                  │
# │ ---                          ┆ ---              ┆ ---      ┆ ---    ┆ ---                        │
# │ str                          ┆ str              ┆ str      ┆ str    ┆ datetime[μs]               │
# ╞══════════════════════════════╪══════════════════╪══════════╪════════╪════════════════════════════╡
# │ x1jqYLksFHSjj-V_dTeZrzR9fFEV ┆ bird raven       ┆ 0000     ┆ EUN1   ┆ 2026-05-31 18:10:37.551072 │
# │ Dt…                          ┆                  ┆          ┆        ┆                            │
# │ QMPPN4oUrY-FW-BBOZ34yDZZmjgh ┆ KaizokuNoOni     ┆ 2829     ┆ EUN1   ┆ 2026-05-31 18:10:37.860377 │
# │ Pa…                          ┆                  ┆          ┆        ┆                            │
# │ yf1OVyzGtKFWKAh__NIUFtnEisdo ┆ Nolba            ┆ EUNE     ┆ EUN1   ┆ 2026-05-31 18:10:38.176115 │
# │ hM…                          ┆                  ┆          ┆        ┆                            │
# │ gw0udTm33m9cDPfENXndpjlXmkHw ┆ Defenser         ┆ EUNE     ┆ EUN1   ┆ 2026-05-31 18:10:38.472933 │
# │ xl…                          ┆                  ┆          ┆        ┆                            │
# │ tD8QYcsn9jmPaM7AACN9Id2fwgus ┆ Dioklis          ┆ EUNE     ┆ EUN1   ┆ 2026-05-31 18:10:38.757716 │
# │ fN…                          ┆                  ┆          ┆        ┆                            │
# │ …                            ┆ …                ┆ …        ┆ …      ┆ …                          │
# │ dYiEC-ravKg74XNQMp4KsOp4S7aV ┆ black nails      ┆ 988      ┆ EUN1   ┆ 2026-05-31 19:15:39.289847 │
# │ lR…                          ┆                  ┆          ┆        ┆                            │
# │ ZLw_1J27yiyrFC_UN7-Uck-IyYMB ┆ AleEmotkaZostała ┆ RMJ      ┆ EUN1   ┆ 2026-05-31 19:15:39.630180 │
# │ LL…                          ┆                  ┆          ┆        ┆                            │
# │ 0CPr6RzHVit2UWf0Cu0EXPbIj77e ┆ chiefelo         ┆ 0314     ┆ EUN1   ┆ 2026-05-31 19:15:39.980448 │
# │ ko…                          ┆                  ┆          ┆        ┆                            │
# │ voxGacYDhQ3ptNab4tGe6ipPP3nZ ┆ Adam             ┆ RANK1    ┆ EUN1   ┆ 2026-05-31 19:15:40.353129 │
# │ fc…                          ┆                  ┆          ┆        ┆                            │
# │ eMwumb2gCUrYSrSf3D1t_9CyIv3k ┆ RAKIQ V NARGATA  ┆ WAGMI    ┆ EUN1   ┆ 2026-05-31 19:17:14.901659 │
# │ PH…                          ┆                  ┆          ┆        ┆                            │
# └──────────────────────────────┴──────────────────┴──────────┴────────┴────────────────────────────┘

# %%
from datetime import date


BASE_EUN1_URL = "https://eun1.api.riotgames.com"

headers = {
    'X-Riot-Token': RIOT_PERSONAL_API_KEY
}

def get_player_snapshot(puuid: str):
    player_icon_url = f"{BASE_EUN1_URL}/lol/summoner/v4/summoners/by-puuid/{puuid}"
    response_icon = requests.get(player_icon_url, headers=headers)

    if response_icon.status_code != 200:
        print("request failed with status code on getting player icon", response_icon.status_code)
        return response_icon.status_code
    
    response_icon_json = response_icon.json()

    player_challanges_url =f"{BASE_EUN1_URL}/lol/challenges/v1/player-data/{puuid}"
    response_challanges = requests.get(player_challanges_url,headers=headers)

    if response_challanges.status_code != 200:
        print("request failed with status code on getting player challanges", response_challanges.status_code)
        return response_challanges.status_code
    
    response_challanges_json = response_challanges.json()
    
    total_points = {
        "level": response_challanges_json["totalPoints"]["level"],
        "current" : response_challanges_json["totalPoints"]["current"],
        "max":response_challanges_json["totalPoints"]["max"],
        "percentile":response_challanges_json["totalPoints"]["percentile"]
    }

    player_snapshot = {
        "puuid": puuid,
        "snapshot_date":date.today(),
        "summoner_level" : response_icon_json["summonerLevel"],
        "title":response_challanges_json["preferences"].get("title",None),
        "profile_icon_id":response_icon_json["profileIconId"],
        "crest_border":response_challanges_json["preferences"].get("crestBorder",None),
        "banner_accent":response_challanges_json["preferences"].get("bannerAccent",None),
        "prestige_crest_border_level":response_challanges_json["preferences"].get("prestigeCrestBorderLevel",None),
        "total_points" : total_points

    }

    return player_snapshot
    
get_player_snapshot(players["puuid"][0])
# Out:
# {'puuid': 'x1jqYLksFHSjj-V_dTeZrzR9fFEVDtcRFuZ0u9novIzvQW-QF-dE9YyTxsi08KU5rAUNccN9F2wLXQ',
#  'snapshot_date': datetime.date(2026, 6, 2),
#  'summoner_level': 158,
#  'title': '10320704',
#  'profile_icon_id': 3789,
#  'crest_border': '1',
#  'banner_accent': '',
#  'prestige_crest_border_level': 150,
#  'total_points': {'level': 'SILVER',
#   'current': 3365,
#   'max': 29680,
#   'percentile': 0.335}}

# %%
player_snapshot_arr = []

current_index = 0
for player in players.iter_rows(named=True):
    current_index += 1
    if current_index % 50 == 0:
        print(f"progress {math.floor(current_index / len(players) * 100)}%")

    try:
        player_snapshot = get_player_snapshot(player["puuid"])
        while player_snapshot == 429:
            print("retrying after getting rate limited")
            time.sleep(121)
            player_snapshot = get_player_snapshot(player["puuid"])

        player_snapshot_arr.append(player_snapshot)

    except Exception as e:
        print(f"Error fetching snapshot for {player['puuid']}: {e}")
        continue

player_snapshot_arr
# Out:
# progress 1%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 3%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 4%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 6%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 8%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 9%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 11%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 12%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 14%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 16%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 17%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 19%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 20%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 22%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 24%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 25%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 27%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 29%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 30%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 32%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 33%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 35%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 37%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 38%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 40%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 41%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 43%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 45%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 46%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 48%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 50%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 51%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 53%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 54%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 56%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 58%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 59%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 61%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 62%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 64%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 66%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 67%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 69%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 70%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 72%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 74%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 75%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 77%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 79%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 80%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 82%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 83%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 85%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 87%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 88%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 90%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 91%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 93%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 95%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 96%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 98%
# request failed with status code on getting player icon 429
# retrying after getting rate limited
# progress 100%
# [{'puuid': 'x1jqYLksFHSjj-V_dTeZrzR9fFEVDtcRFuZ0u9novIzvQW-QF-dE9YyTxsi08KU5rAUNccN9F2wLXQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 158,
#   'title': '10320704',
#   'profile_icon_id': 3789,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 150,
#   'total_points': {'level': 'SILVER',
#    'current': 3365,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'QMPPN4oUrY-FW-BBOZ34yDZZmjghPaYoJqNongrmvIJJkD9MtNUvJG1FdgQcvywW23L_s_bA83HIWw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 84,
#   'title': '1420',
#   'profile_icon_id': 7063,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 75,
#   'total_points': {'level': 'GOLD',
#    'current': 4595,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'yf1OVyzGtKFWKAh__NIUFtnEisdohMl-BIbvNfGtsk66yCvUNmURprF9LJxvD0s7X7w4FYOXxJtHig',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 32,
#   'title': '1',
#   'profile_icon_id': 15,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'BRONZE',
#    'current': 1485,
#    'max': 29680,
#    'percentile': 0.434}},
#  {'puuid': 'gw0udTm33m9cDPfENXndpjlXmkHwxlRKeeRlxptTMvXhMZin9UmJscHevIDj2CJX7RJTOiiaZ5X2SA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 108,
#   'title': '40240802',
#   'profile_icon_id': 657,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 75,
#   'total_points': {'level': 'GOLD',
#    'current': 4625,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'tD8QYcsn9jmPaM7AACN9Id2fwgusfN_aDOvKoJE6AUyeKzyrUoBOmXKYwBLSyvG2j_xFT5DnO6zUOA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 143,
#   'title': '40130204',
#   'profile_icon_id': 6893,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'GOLD',
#    'current': 8455,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'Ex6oHbe6BQm-nlAGY5dG7OIq5x5MWpWiwDj5UadP7JYfHR4JPxUXlISDfSY6qOU3xFK-F-RtLj2mrw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 175,
#   'title': '30130106',
#   'profile_icon_id': 539,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'GOLD',
#    'current': 7275,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'xlXYoWhWfkG96A8YPhWM4k5gN7Q2Z_GeVKUMR1tzXOMkJ3Ml4YGa4xThZJmfuF9q38p03JyE-CKZOQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 178,
#   'title': '51000603',
#   'profile_icon_id': 7063,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 175,
#   'total_points': {'level': 'GOLD',
#    'current': 5870,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '-WvQ3AIG5_g1aDkg_QHQ-sbwo2P3ApYkF__fo2FsHgrCn8279YoaLDnSuCCMsexg42PetD1FtZedqA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 35,
#   'title': '30230302',
#   'profile_icon_id': 4533,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'BRONZE',
#    'current': 1585,
#    'max': 29680,
#    'percentile': 0.434}},
#  {'puuid': 'NpnvbPm9mHNXrSzKBfMzxfPqfMVzIET9YNLO6OUE5c95ehbyKiFuc4ug4TglMAh1e6AyLgoiToZf3Q',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 169,
#   'title': '20243007',
#   'profile_icon_id': 7120,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 150,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9305,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'zr_Slr-EtH2JmkmH7TRaKP4aoMgzVYNjHwCdI8K-kWmtmP0mUMx305ZsomtHxEqqjciv7pCBmeieMQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 53,
#   'title': '50500005',
#   'profile_icon_id': 1391,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 1650,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'cmf9Wq4VPLC2kdxoVfNNUUnHDCTju0L-uXN85uQdd1BYfMyLmqWpkuHuhJJaUiKiN-9mVjjxcNsVwQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 49,
#   'title': '10320503',
#   'profile_icon_id': 6050,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 1865,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'CcG_Gnfaoc3Kmvta_hGfzj_hJboNG94m0GLz95UNtpv0ZWOajFwop-8evn51I95zUM7i_1FfEisuqA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 464,
#   'title': '30230005',
#   'profile_icon_id': 4272,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'PLATINUM',
#    'current': 12700,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'q-EGxYoL0CmxyxkJXHauvq7nTad_poN_z6hxY9X9PaNIgYnxefV8Uvi2GlhR1Cvbr2cG8V-imPDarg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 223,
#   'title': '30110203',
#   'profile_icon_id': 539,
#   'crest_border': '2',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 150,
#   'total_points': {'level': 'PLATINUM',
#    'current': 11630,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'isSBTv0HLpPg8rDayF8OyHrhc_WZYm6kiIYQFNf_IzakV1Js2aoN6Wi5prSVfU7L8aisy-3DGn1_2g',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 74,
#   'title': '40130504',
#   'profile_icon_id': 23,
#   'crest_border': '2',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'GOLD',
#    'current': 5395,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'ZPinSKzU_Wvya_v1HE63RzJ8EO1TU1_jJ1oxClgVXkV8PKjKcJ-sKDZSbZ7frYlQwsv8GDpQRZcyXQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 72,
#   'title': '',
#   'profile_icon_id': 6763,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 2995,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'Ucd7WsUkFVYCCTNzr61jnmG66VXrkIv1kkr8x20Upoo-S2Ku7SyDqvTtkTX48CCg7pJeoYa1Gpujyg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 40,
#   'title': '20230204',
#   'profile_icon_id': 3901,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3270,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'APtcQ7Yrb7feq6frECvN6Fe4xjUX4kh21UBs9wDZBJvvPVDPp6Y_jNg37aVxbUOybG1B15IIxg-_HQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 45,
#   'title': '10330005',
#   'profile_icon_id': 5408,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 4190,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': '_yS_49PEpnKhr8glwp4p6Vrllg3l2LKk0_MvUBKifb25SV7cdX2cJ0PzX1r7y9Cm9lh5xqHIm_IWyg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 35,
#   'title': '',
#   'profile_icon_id': 938,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 1,
#   'total_points': {'level': 'SILVER',
#    'current': 3340,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'iVt4eEZIo_rBbddO4I_Khd_bZKKympzh4PwSL6Pu4MkyRadwtfmJCkkZdUXqfWFG4fhHPNlgL7DGxw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 134,
#   'title': '60300007',
#   'profile_icon_id': 6105,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'GOLD',
#    'current': 4720,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '6ItvcmArYTRCd4l-y0EmjH3F-WvgLFrlIb5W25k5h8whYP1ZE6irWwzgLTwKRZeSGbX6oidB8Sdhpw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 139,
#   'title': '20340502',
#   'profile_icon_id': 6804,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'GOLD',
#    'current': 6470,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'At6Rz1zHubpKmKfOUG44tLvCSgTTKUXS-Vk9aIK4BW5oF5r0nTGoA2HihImk9TYAbOTyrIV6kjaywQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 218,
#   'title': '',
#   'profile_icon_id': 6446,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 150,
#   'total_points': {'level': 'GOLD',
#    'current': 7370,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'cYgOaFQ4BX96snjsmokXzsba5i70_jMZbEe_QcHAq7VXxCqmwcAr9FmyrqKJYWeiLwux2cb_09fPvA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 146,
#   'title': '',
#   'profile_icon_id': 7,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'GOLD',
#    'current': 5575,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'Hil2k-BFBHJOX6_HwL412OrFT51bXq5wk0SihgZyRKJiJVAxovT8fxze38Evvj767rX0DuBRvykRyw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 192,
#   'title': '',
#   'profile_icon_id': 5413,
#   'crest_border': None,
#   'banner_accent': '',
#   'prestige_crest_border_level': None,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9435,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'CeRPqUHUdaae_wc0NdAUnUwsSpSlzP5B91Zo5gBCwuaAt6v86B6LiXMzEAw74aJQgg6ylvU78RUKxQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 186,
#   'title': '20100304',
#   'profile_icon_id': 4982,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 1,
#   'total_points': {'level': 'GOLD',
#    'current': 7720,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'Pry5fB1RwnffueYbPKXQmKvH8tfIyNawKaynghF8kFjR1pe_CgsiU76x-uBLJVQyYek24IlmcyRGng',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 330,
#   'title': '',
#   'profile_icon_id': 7,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 275,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9700,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'R9LOtZA5nfnCd0nrWaSaaZB6_UBf2ESn-tSGRN9r0IeYHpf1roPXg13SmvGTx55-UJvf4hzPl367TA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 323,
#   'title': '40130104',
#   'profile_icon_id': 1666,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 200,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9990,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'eJaDR6eSdgdYQVrZUbQmZ8sc_VhOZJrhrKmXJQukN2RCctneZWHjVoEYbB01sGMQkiWet7J9ynnOGw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 147,
#   'title': '',
#   'profile_icon_id': 3840,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'GOLD',
#    'current': 5350,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '0-ywEifYkSFBA640XHBQx74nrzA_G6Nx0QdS0hbCobejyT8Yn4Jb5uP6jFx7ebP9KffaDAbjsZWt6w',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 68,
#   'title': '30130005',
#   'profile_icon_id': 7078,
#   'crest_border': '2',
#   'banner_accent': '24',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'GOLD',
#    'current': 5460,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'vX6rti8CZL1QfJZbskooR-n-XLGyj_AKxQsfcGt01KEuy58azdGC1EjqNH2045ZTIz7bZEDkQ-eVmg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 35,
#   'title': '',
#   'profile_icon_id': 580,
#   'crest_border': None,
#   'banner_accent': '',
#   'prestige_crest_border_level': None,
#   'total_points': {'level': 'BRONZE',
#    'current': 1560,
#    'max': 29680,
#    'percentile': 0.434}},
#  {'puuid': 'cu27xYBGOIeT05RgAEqv3WYScDhWi2LkSfpE-60GOEgyFvEbe3iUzbo-yYVU-DbcP2rL3PU-JbRH7Q',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 64,
#   'title': '40130404',
#   'profile_icon_id': 5994,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'GOLD',
#    'current': 4525,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'zRWiSBVddGJlRdMzkTQAFY_mA0lhzEXWUEUwKPrxfoFtg-V-yx_lmPmZVyDbFk2U6uNEUmqtNjFSaA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 47,
#   'title': '',
#   'profile_icon_id': 507,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3050,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'AeV_pnibHeIN8eoG5ilyiV63YG6Wd5I5GvqJJ1UZaPBC4TS9sPDtsDNs4QS6tfJUdaArBJ0kPlAChA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 121,
#   'title': '2000099',
#   'profile_icon_id': 22,
#   'crest_border': '1',
#   'banner_accent': '24',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'SILVER',
#    'current': 2510,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'rOIPzJ_RXHZZE2kYN38Tgl5nFBWgp_O5uqbdW7E0qtoCyXCt0F8arMS3V4e6mVH6k_SJI3Cd313jAw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 100,
#   'title': '1432',
#   'profile_icon_id': 6753,
#   'crest_border': '2',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 75,
#   'total_points': {'level': 'SILVER',
#    'current': 3530,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'JtYl21x-bZS10TZjvhQVy7vlTruN3uEh1bQKEOnrXt70zzo6rpFWvJfOKoQy46RPEOKBvsRdwgSQLg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 427,
#   'title': '2000030',
#   'profile_icon_id': 6759,
#   'crest_border': '1',
#   'banner_accent': '15',
#   'prestige_crest_border_level': 425,
#   'total_points': {'level': 'PLATINUM',
#    'current': 11700,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'fPQfDmULV0skrhoaxlau2uYMpN-1j_9_s2eXAMvLiCS63xQKVhzeIdOBSU77jzIzoyjPECkjfgNshw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 109,
#   'title': '',
#   'profile_icon_id': 4881,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 75,
#   'total_points': {'level': 'SILVER',
#    'current': 1810,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'fTET4_-_Mt-Jte-CMzQf-yQ-JfPXy10xCLAIcYbZtkGye8q3Q0C3hBKl-cjc6rhE2EvVlWboCQKnlA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 68,
#   'title': '51000603',
#   'profile_icon_id': 505,
#   'crest_border': '2',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 2710,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'lDQYBoA7yRH0WDvmPy2rZlOdB3TCSJuI3vFdECawBIixlSsG1GnPiPTTeerlJ7etIea0c0c8rM2mRQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 31,
#   'title': '20310203',
#   'profile_icon_id': 5993,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 2155,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'k5uIBcKTnOzDXXzl_imwp0TW2bPZ-pPHDOx_2AMv8IIlweMXxO36-HkkwQIqxmO9MiEyoExP1szYiA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 33,
#   'title': '1432',
#   'profile_icon_id': 6103,
#   'crest_border': '2',
#   'banner_accent': '24',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'BRONZE',
#    'current': 1285,
#    'max': 29680,
#    'percentile': 0.434}},
#  {'puuid': 'Jjvl4ZX6Fgxb3i_sLf7NnjR7K0NCfgLX2TQQpSRO0a1xnl9qMULtf24VjCUWvS6sNFAMzle9rfv2ow',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 108,
#   'title': '40130504',
#   'profile_icon_id': 23,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'GOLD',
#    'current': 8275,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'YPVmkXRhCAFU5geb6K3w07zSJSr-l1nLLIEH-NtX-AA5PfsGU-jrwF9HJzlqyq8ke--pi-3LSnq0HA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 216,
#   'title': '10110403',
#   'profile_icon_id': 6733,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'GOLD',
#    'current': 6805,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'Q2b4CORoeSzOmHQuWkWnO60EvXcxxjj6vh2sfTN_lJDdPSeEtKCS4AdASbwhBnwIPEE0GCvrK6Fbrw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 174,
#   'title': '40250104',
#   'profile_icon_id': 3398,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'GOLD',
#    'current': 6925,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'H7vARm5oeiOSeVICNzDt_SJfziTfQTiC6VReMCZ4MZ7g5wMdL4Xsx5BTcnqKNqnymcuoTOjsRCfciQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 81,
#   'title': '50500005',
#   'profile_icon_id': 5903,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 3045,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'l36iy8cZBY7KfSqtCUc121Y9Dxp6710nmA6MKz7Kl24t_rkKmc-22LS9D1oF7qqQIsWiOkWW3DjUTw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 129,
#   'title': '10320704',
#   'profile_icon_id': 6622,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'GOLD',
#    'current': 6175,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'mRW1gozSC6d7eus3CwnNpClr_VBoZBDnTEumaHzQf9gmesxS_-Zmaio9crdS8I7tB-PJ11NpqpBXdw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 69,
#   'title': '40130304',
#   'profile_icon_id': 23,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'GOLD',
#    'current': 5410,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'LZKYcEbgoh2sxJy8fb0PtgITSU9zVZUFYiw7PtDEw_rXSxIAso7a6ipAUzHvoacy2oC74l0ec3kPbA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 221,
#   'title': '2000105',
#   'profile_icon_id': 4492,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 200,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9155,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': '-RQYuP6KubT0fQXlxRFH4xdhiToHVFUhZLNEXKVPAeBTM2eiO7QIN1Md1okT4o44QXDDBxzoLcP7SQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 112,
#   'title': '20320104',
#   'profile_icon_id': 774,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'GOLD',
#    'current': 4440,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'LQBPV0etynRTa9mHm-o_gdD5InlhFUvxa5a6GUByDkIWej8IIfFF-NRstOjby6GZIlYbXa4OHrtyUw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 179,
#   'title': '',
#   'profile_icon_id': 503,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 1,
#   'total_points': {'level': 'PLATINUM',
#    'current': 10050,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'Y_4A_i2DKrkgijyu77OUCV_kCoJbxIg7loFsX-sLk0_SHyAEynHAuOLokv95OgEtNMkkW16NwmvK3g',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 68,
#   'title': '',
#   'profile_icon_id': 589,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 4205,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'mt9T7L1-wGWekbBU4wzDDT5RGRV3YaVrUe_sAnMGxv91NAyeNqvN0CEuE2pEAt-ZB7DM-o9qW3aoXQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 166,
#   'title': '40130204',
#   'profile_icon_id': 6894,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'GOLD',
#    'current': 5890,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'qWl20Hs9MMa9RcoGtzXEA3QuEn1oEaUjNMsMHAfEszT4YxdM0lZ-aPf-f31Lsm0Re6xrMaVZIORG8g',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 189,
#   'title': '1432',
#   'profile_icon_id': 7099,
#   'crest_border': '2',
#   'banner_accent': '25',
#   'prestige_crest_border_level': 175,
#   'total_points': {'level': 'GOLD',
#    'current': 5665,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'Yv0HMHPs1YDNcYhRJC4i39e2xmCVVfQ7GBZ0T6hXB3saXPp__02q0yxU8FTgdTIa36z1uYFzwwEsWg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 124,
#   'title': '',
#   'profile_icon_id': 518,
#   'crest_border': None,
#   'banner_accent': '',
#   'prestige_crest_border_level': None,
#   'total_points': {'level': 'GOLD',
#    'current': 7110,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'twd7Ns30GevhNbOAOBhpnHXchhUF7NtLRHBWTEG8S1s_jgILf1yyZkNq800NzUDWvxAT6n0YddB_VQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 58,
#   'title': '40240802',
#   'profile_icon_id': 4216,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 2265,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': '61dxAwpmqJjHmDRHJv1-j7K5P1fJUogyUqxO8LcOav35Rl8g_E13Ki9Qc2rrAbV4u7BfoXnsb6nO_g',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 32,
#   'title': '',
#   'profile_icon_id': 6864,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 1,
#   'total_points': {'level': 'SILVER',
#    'current': 2765,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'EupoO15bsODjde6Lk0fMdkrzRgC7HCeBHXQMmhYIAXodQtaelKkaTlU096ov7BPAw278ibhi2ZXSDw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 91,
#   'title': None,
#   'profile_icon_id': 9,
#   'crest_border': None,
#   'banner_accent': None,
#   'prestige_crest_border_level': None,
#   'total_points': {'level': 'SILVER',
#    'current': 2165,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': '3fOQaz-011Vmi_O2cjRo_xq0HcKW_gcIIsbt8fXb7OJdblr6X3q09hQ3DHELjKfCql8Ee7QKgdW1cQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 103,
#   'title': '50500005',
#   'profile_icon_id': 4403,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 75,
#   'total_points': {'level': 'SILVER',
#    'current': 2410,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'u-reIUSHOsbqDZKxfHI5tnSr8rQANgbxvAur3GP8W37lGCGev1SQB7pBy3ONQfwaT9c_LDR31X5FPA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 408,
#   'title': '',
#   'profile_icon_id': 5916,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'PLATINUM',
#    'current': 11610,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'vJxHFMJn6DCeCZUgvmQfdzpFj6EgSV4uMF1gzlX1J9mBcP7ICMN_n_d-ROSLULqCwQ_YaZzVaMfpCw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 166,
#   'title': '1427',
#   'profile_icon_id': 7070,
#   'crest_border': '1',
#   'banner_accent': '23',
#   'prestige_crest_border_level': 150,
#   'total_points': {'level': 'GOLD',
#    'current': 7680,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '24PsmoQjSRJqG2pQXBWtqz_WSGzOqUpG2IKHmNRjoQjSc_RIZOOSsAkCvfqBHKJgx8AaRadlbahEHg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 343,
#   'title': '10310005',
#   'profile_icon_id': 13,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 225,
#   'total_points': {'level': 'PLATINUM',
#    'current': 11910,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'eL-TL_KBGzjgnTyUg6u50VFqm8ZcwSuJ_FZNnGIJYm9sL4GzSgeNoycLZso9YL1invzViXcwndS4YA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 48,
#   'title': '1432',
#   'profile_icon_id': 7128,
#   'crest_border': '2',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3985,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'KGY8-b1UQxwzuf9-zrcoZQ0--M_0Bkb2HqsCseO-ErHtqHJE44cxM1vxzH6q7M1xdwGkopbTmiAX6g',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 60,
#   'title': '',
#   'profile_icon_id': 5799,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 2605,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'RRcA6c1YoNUvuHSU89XzTYfgxuyeuG5emk675mj6sRvaHQSpoQ5bgpCKyLpE2XP-V0TbJojWM6pA-w',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 49,
#   'title': '40240802',
#   'profile_icon_id': 5337,
#   'crest_border': '2',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3870,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'eXeR3JdlWUk6XC-LAGlKDHnsZP-iPlHc-0ALQj-LHCVUKSEAvi1aaFPOmaLEDRZerzmx8lkcalbFNQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 114,
#   'title': '2000136',
#   'profile_icon_id': 938,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'GOLD',
#    'current': 5915,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'eYmlJkm_ovQyV_dIySWgnIgux0nDVlWSbPHjx5Bn_ALLZi0yDxlV1icshKuelxFmTCMYVyKVi5GfDw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 118,
#   'title': '',
#   'profile_icon_id': 5918,
#   'crest_border': '2',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'GOLD',
#    'current': 7230,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'bElKIqoTmIfLFBD0wRE30Pobo6EhTSQgjcPGvMd_hefPSE2DXMkmx0HNV2muAhlG_xra3QKz2LK8FQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 74,
#   'title': '',
#   'profile_icon_id': 937,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'GOLD',
#    'current': 4495,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'udY9pX5cbscK92hUjY3RzSF3KCFd5EOAjNAGaE75ipoG7HiwFQiE9eJbTBe8D9vpfJ-L1jEURG5vVA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 46,
#   'title': '',
#   'profile_icon_id': 664,
#   'crest_border': '1',
#   'banner_accent': '24',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'BRONZE',
#    'current': 1210,
#    'max': 29680,
#    'percentile': 0.434}},
#  {'puuid': 'MY0LJOSO3DaVg6xnLOjB4_YnnIgrc4GX_JGgB1mbUNeMgJHi7zVOCVaGU7OGrVyltNuegGcdssbuqw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 67,
#   'title': '20100304',
#   'profile_icon_id': 7094,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'GOLD',
#    'current': 6525,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'pJFH9Q_JcDunJjTaoyuHU0UJ2_7H1awFkqPP0yao0Wsxde6r3c4H54jsm2veW4rZ5645EkXPnTM33A',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 49,
#   'title': '30120104',
#   'profile_icon_id': 6650,
#   'crest_border': '2',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3500,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'Uxx_R4vwiVO_WlKog2Z8uOuyAs5UH2dH3hrvKK6E0Cnvnuxt7v_wyvUaIcUVHh5AXXXmobbmu1dFGA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 84,
#   'title': '',
#   'profile_icon_id': 6331,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 4120,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'YIKKzIK4X-hBT70lAhduj5xQhrbSJOpoXrP2Bh0UM8Zf3-azg1oV7n_Uh4z4xQkmY4XxCav5jaTyTQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 164,
#   'title': '1413',
#   'profile_icon_id': 580,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'GOLD',
#    'current': 6140,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'hlpJpmuBeSMfFdujiI9LVSyvsomJEZvFoUnooNuiKNzwgOr6MLK1fHVPgqnMtw4jX8XWQr6cGq_jMA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 49,
#   'title': '20420202',
#   'profile_icon_id': 2092,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3170,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'xREeg0aNucBPr2Jj3k78ZvAUQ9bxoTtoiyJjuTmzgRGZHeVWCq4Ic36kAWHUuMM_zCc2T0hakKaxDA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 291,
#   'title': '40130104',
#   'profile_icon_id': 7098,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'PLATINUM',
#    'current': 11065,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'ZcqaymakVpfDjybwbScSQ9vrVe2iVMWLZwslprJUyAItcrZb4IiDDrqQVFR1BJugIlzq5Is2-ohXKQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 405,
#   'title': '',
#   'profile_icon_id': 3799,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 400,
#   'total_points': {'level': 'GOLD',
#    'current': 6585,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '6aMBfmhE_id6huFj7h-PFC7LZ5pZXmjPQszV51NhTXZTHbg8iGdvNmrFwUIGvfCuB7Kh_A7plwhWwg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 132,
#   'title': '1403',
#   'profile_icon_id': 6763,
#   'crest_border': '1',
#   'banner_accent': '11',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'GOLD',
#    'current': 4335,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'qI84xsyrslKTJJ0k512F3M1WIA3EX_ukECCXxZrAro35HdehL85ka6vTA7ew8I7DxVBRvEWbygM9HA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 31,
#   'title': '30110005',
#   'profile_icon_id': 7128,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3075,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'cjKKeijZu0MqAEmsuVI98DPgn80GpBm96HE9Z2O4-bRtc9uwKpAzu2DOfb2-14RP1DaCgFplWv9Ppg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 90,
#   'title': '20340502',
#   'profile_icon_id': 518,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 75,
#   'total_points': {'level': 'SILVER',
#    'current': 3150,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'sr_RpS662NXNk9EZWtc0E-d43G-UCiSuDaNdUyA2cFLKwiU4Qzp5Res2tuL1yrKAYxWqo2D5mrHwTA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 32,
#   'title': '1',
#   'profile_icon_id': 539,
#   'crest_border': None,
#   'banner_accent': '',
#   'prestige_crest_border_level': None,
#   'total_points': {'level': 'BRONZE',
#    'current': 770,
#    'max': 29680,
#    'percentile': 0.434}},
#  {'puuid': 'vIwg7s-s3xak4XWAQ9bXi4mbZfP6chQw5vhBJ9eN-ZK3LLK3FQ3YCQyscUxhq3F5l9igssOP5yJmUQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 60,
#   'title': '2000017',
#   'profile_icon_id': 1391,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3675,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'zhitAiuq3439JvmSO46q8ayKeFnbgXEoG1YDde3lBYGwLhOep_ZCL92y9rZKSkS1er12jtwiYyqWGw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 110,
#   'title': '40210604',
#   'profile_icon_id': 7051,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'GOLD',
#    'current': 7345,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '8zwaj4zUxPNfu8CTo43uys0wbqlYRnLNZJZTY94d4cR5-aCl6HpBkts1jDYyjGzjboIoX2PYF6gHnA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 288,
#   'title': '20310203',
#   'profile_icon_id': 6097,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 200,
#   'total_points': {'level': 'GOLD',
#    'current': 8080,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'hyAaU_wJFTxLnJHhIUiOY8CZX6JPXhZgGQEs_B6EF256lIVNb6xRWugPtFnYEPtve-Sx7Qeh-WiB1Q',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 41,
#   'title': '10320503',
#   'profile_icon_id': 6621,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 1675,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'C5MFe2iBljK2wacwzrW-ecRe5S2peT1HYgPnrtJfN-3PA26x4yAGpV4yi1VSu1OGYPuQLvU7wito8Q',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 1162,
#   'title': '21000506',
#   'profile_icon_id': 1297,
#   'crest_border': '1',
#   'banner_accent': '25',
#   'prestige_crest_border_level': 500,
#   'total_points': {'level': 'DIAMOND',
#    'current': 18300,
#    'max': 29680,
#    'percentile': 0.036}},
#  {'puuid': '5PR0Mceeh7MPpMOGvIhazGaIBypWBOf8EcnV5VZEgdwRG62jR7RU5iCswPlm8VXhjbxu000FKNYXTg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 158,
#   'title': '40130204',
#   'profile_icon_id': 641,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 150,
#   'total_points': {'level': 'GOLD',
#    'current': 6725,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'vPqQI1Fz1bnN2tFBJzWeb61xagbjXO34cZlmPeodD4_HPfazmd06kmJxI48vtf0nDLzIm1Q5irxr0A',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 138,
#   'title': '40210604',
#   'profile_icon_id': 781,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9490,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': '8TXDd-7lwsEbcu_AoGsjw0ehR9WTqzTZTGO8lPMl2SieG4nzynusaK6zg_rhnih7HEZ_b6rX8rBFDA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 46,
#   'title': '20310203',
#   'profile_icon_id': 539,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 2365,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'qIIjEx7t-5Xgy7H911rPvz7Rs0g5rHCfgj6-fARei3SAWMf6oQ3OltGDGl5UwtodZ8fy4aALP3GJZg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 37,
#   'title': '10120601',
#   'profile_icon_id': 642,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'BRONZE',
#    'current': 1565,
#    'max': 29680,
#    'percentile': 0.434}},
#  {'puuid': 'uu_GUahcJsB7T-mwnukTQC8DjiO03DTX1aPbVlF3Nf0fXAc-JAj3ILNSJ1RoKoANLOaNZWEEjVI6DA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 40,
#   'title': '30110203',
#   'profile_icon_id': 6233,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 1735,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'CQr9Kp6Psp5_G6X5iXqV7X-RoWZ-54NndXkHPFjorpFa2LMgbqibQ_0bPgoSCsTvamG-UQ6QHDm-bg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 202,
#   'title': '30210203',
#   'profile_icon_id': 6070,
#   'crest_border': '1',
#   'banner_accent': '4',
#   'prestige_crest_border_level': 175,
#   'total_points': {'level': 'GOLD',
#    'current': 5090,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'kYmZ-P9ESlNLeTcdIlhHgTlA1FGYZDjmRyxGw1PdeOIsOxmFVHR62FyL04bL-oQ7f6Z_eBks4JyhPg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 35,
#   'title': '',
#   'profile_icon_id': 6004,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3720,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'KB72qJ1DPUJzGcBdkoT1G0RQUctkx7lu4ovZ5rQHGQ7XhIyawPMwYmoyb_D5PvA8hO-PS8w8XFe3Cg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 271,
#   'title': '1401',
#   'profile_icon_id': 5025,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 250,
#   'total_points': {'level': 'SILVER',
#    'current': 4200,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'uYwPYIQJ98Eo0y5L2j0-I03Bjgt0gl9RVpuChVDR_xICGxFYr-9IPzxuAjdXlXLs-Jb3L3mlFox45w',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 108,
#   'title': '50500005',
#   'profile_icon_id': 6094,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'SILVER',
#    'current': 3310,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'otgiYKCAuaHQ8WtEHjs5-fwXUwNkgmJi96kokxeH4whxIjt9jaS8XxueZpkyFYPNJVIFBXD5VOse4A',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 47,
#   'title': '30110203',
#   'profile_icon_id': 7094,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3520,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'Ngvi_SuPn7m-DtVLgX1cc3YC80B_Fyzu3sZWCcENAhIHLu5vxTp-esS4Uy96rYGmjnOPIArDc_xhZQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 113,
#   'title': '30210203',
#   'profile_icon_id': 6012,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'GOLD',
#    'current': 4880,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '-A-y7ciJedhSlHR-gb4TxTzWG2gTkKgWjBhah-xtiDLLiH6d40XD5vZoG8fqEaxcrZd1OzkebB_l_Q',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 33,
#   'title': '30120504',
#   'profile_icon_id': 7,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 1,
#   'total_points': {'level': 'SILVER',
#    'current': 2565,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'M8NKgIZR9TpaCJUQTbwQPf2Jzz-lVt5MJm_jREr16tenmm140JAQAM3CfNjzSIGcv0t2NBTTYizEcg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 57,
#   'title': '1',
#   'profile_icon_id': 19,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 4135,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'PuhWPvu7j7M8dyny4nW8HeWI6HzdZ24qkXG_bmNrL4EEvXk6nAuolGLpW931a1B3xfkZBXID6Un6xw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 149,
#   'title': '',
#   'profile_icon_id': 3186,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 1,
#   'total_points': {'level': 'GOLD',
#    'current': 4840,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'qcYm-6pVkpO8kyMR5wnJ1paFPc_yx9xT49mInuP5m7XwLBsYobGbTjV0kepmCsG2RwRV4YuqDe_kiQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 256,
#   'title': '40210903',
#   'profile_icon_id': 7128,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 250,
#   'total_points': {'level': 'PLATINUM',
#    'current': 11330,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'gUf7hO_hoLs-uSS-187PiL3VNI_1jkbY8ARnBw1D_JV-hf_SEE8UuanH5vH1eKBnN6AjfN0_SBJeUQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 32,
#   'title': '20230204',
#   'profile_icon_id': 3589,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 3160,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'k6EszfBqZ5KJg6qeARNkvke6C0tpzls5O8tOw2V7EIE4_obiDyUppuFIsZ9acoBnCvXY9dN3XDS0PQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 88,
#   'title': '30110203',
#   'profile_icon_id': 7096,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'GOLD',
#    'current': 5280,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'gqWmdeALhnO6EypnoHWs6wyAhCKWRwBMrFOvBRzvxR62eo4F64iYAas_qeV-VbLFO1fb_zMqnkD4Ug',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 237,
#   'title': '1423',
#   'profile_icon_id': 7064,
#   'crest_border': '2',
#   'banner_accent': '24',
#   'prestige_crest_border_level': 225,
#   'total_points': {'level': 'GOLD',
#    'current': 8455,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'ukMzoCo8Uw-xivit_CN2IKAC7uG4YkypUszu-jDEhLlu5W49PZPx2g-FKh4EuNIsphhtiTdptbvhbg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 60,
#   'title': '50500005',
#   'profile_icon_id': 5987,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 4025,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'JLtv5pU80fC7UVeq9qsxTwCPtyGJ0oKJ1pHg5nX_WgMHoV-GHQjV_ttuI_24CZFzKWcJhD07PIu5RA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 233,
#   'title': '',
#   'profile_icon_id': 665,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 225,
#   'total_points': {'level': 'GOLD',
#    'current': 7730,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '2e2Yci31HZUmoUX6xJ74kbgdSNiBWqERVdlLIpYTcQ25W9nHg70vKSAYL5mg0u2FfMM0e2xzeyLkLg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 222,
#   'title': '20220204',
#   'profile_icon_id': 4025,
#   'crest_border': '1',
#   'banner_accent': '25',
#   'prestige_crest_border_level': 200,
#   'total_points': {'level': 'PLATINUM',
#    'current': 8950,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'euHhR2cPdOCw9pBOTJSsy_3FYWd9W7cT4AzSpRvNqUNY9c1sbw4EdEULNFjFc1XcIMJLav4EcyxikA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 88,
#   'title': '30110203',
#   'profile_icon_id': 7126,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 3610,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'dvZBTtA8IGas5AApxC5P1GbY3tR3A-Qsk2oJTKmN4sthjoZqSPsVOFgBArXcJRsRA_dT_Jd6nGXrgg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 41,
#   'title': '10320503',
#   'profile_icon_id': 7094,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'SILVER',
#    'current': 2420,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'Fn51MIwh6zDuhdOJZueDXx47-NJ22P8EybPtjdUjYrUyzOv99p6SkXR9FCSAwpFi8ERpS3hfWjtxnA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 68,
#   'title': '',
#   'profile_icon_id': 27,
#   'crest_border': '1',
#   'banner_accent': '1',
# ...
#   'total_points': {'level': 'GOLD',
#    'current': 5170,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'm_dlZsy57EhKYQATNP_QIZKdCZbUbHxnPl92eM58OE7ptJ3AvZiMdbFw3GEZUWio0rRsMhdkkwxi-A',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 172,
#   'title': '50500005',
#   'profile_icon_id': 1430,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 150,
#   'total_points': {'level': 'SILVER',
#    'current': 3310,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'sYbNTYktJIOrMkpIWGM5oJJTweDM_e6R-t6uDYhEamDRnjwD-3Kc7Q1ICxSjAAzM4pO79g0igN6gCA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 137,
#   'title': '30210504',
#   'profile_icon_id': 3458,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'SILVER',
#    'current': 2620,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'UekX7XddUUZS9ygrYEDGEux_VvL9T_qeiXEGnfHzjFSgqH665tVPPRKwaZaa8xepLLWaLA7EfDY-CA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 143,
#   'title': '50500005',
#   'profile_icon_id': 1154,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'GOLD',
#    'current': 6710,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '1fYCni_dHL1GxAp3z5x7sho5IfXnKLb5Rfi6CUqqElP09rBRds8pSJqvchkQQnLDMKn8EfasWIjL8w',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 326,
#   'title': '',
#   'profile_icon_id': 6923,
#   'crest_border': '2',
#   'banner_accent': '23',
#   'prestige_crest_border_level': 300,
#   'total_points': {'level': 'PLATINUM',
#    'current': 11600,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': '1XnUFqH0Cahpk5XTXKXQpAAKd3MpVmTKP4uxVLk-tvEAECT8XTl7PlTB-VxwJdQX-vMJoNnW09Aglg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 310,
#   'title': '60200307',
#   'profile_icon_id': 4792,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 175,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9775,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'vblrXvReTfpuFaMw0uuipMg4tojJmqHyVoZtEYvUxtaSTGGiplwJcsnVCBOHByCAOS9yvMhhLyaKdA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 196,
#   'title': '',
#   'profile_icon_id': 6733,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 75,
#   'total_points': {'level': 'GOLD',
#    'current': 5810,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'ybNQnLfD2VJm70KO9wknmJTQnX2uP8SDKWAYFL3kMXUM4nvGf8bcsoICXzCya6dtRFwe51_G-Tv2wg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 539,
#   'title': '50400204',
#   'profile_icon_id': 3014,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 500,
#   'total_points': {'level': 'PLATINUM',
#    'current': 12155,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'uvXSNnVQ8aNi-2wASL9MR-w_bnJ4XJYnPVUo55PXmYcFiyvnsA4V8Q1r2EDQPksZpKdcerClirbyug',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 319,
#   'title': '40130604',
#   'profile_icon_id': 3017,
#   'crest_border': '1',
#   'banner_accent': '24',
#   'prestige_crest_border_level': 300,
#   'total_points': {'level': 'PLATINUM',
#    'current': 10875,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'Tb3CHWFD4jSr-e-YBcobk8oWC9ecHW6hbzJRBMQQ6t_VQUSa1ShSMoUx2Fa1GcWpnvdNK0xGmOWQ1g',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 66,
#   'title': '10320503',
#   'profile_icon_id': 539,
#   'crest_border': '2',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'SILVER',
#    'current': 3370,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'FwW9yk0UbeKvuYDKc0LHLrmVGSePcfABj6OZ660BjiBIWgQHiXW4CSGjMrtJ3d90qo2AguRrXNk0vg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 119,
#   'title': '30210203',
#   'profile_icon_id': 693,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 75,
#   'total_points': {'level': 'GOLD',
#    'current': 5660,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '5ejzjCzwkZJ5bSu12J8DblMJYq-wtTSHaVNGyPE6N24mhaf7KRkZXSUvCRObEvTJH3YCIo3gsDozyA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 294,
#   'title': '30230302',
#   'profile_icon_id': 6066,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 225,
#   'total_points': {'level': 'GOLD',
#    'current': 7750,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'G91aF1evHWYYRClznjsiUMmmhXaa4xScWCZ6UE37Xerr0sG5fIvFWxxaAodEVrPktcvqLN776yFE3Q',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 194,
#   'title': '51000904',
#   'profile_icon_id': 1296,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'PLATINUM',
#    'current': 8905,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'Ol_Y4m4y6HJ-UilBTFwdoQvvVNRYkE2IfjDpzNnuv1dVeIepY1YGV0-3vaTa7iWZXMIB5QTIBAk1aA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 129,
#   'title': '1',
#   'profile_icon_id': 5367,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 1,
#   'total_points': {'level': 'GOLD',
#    'current': 7465,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'ypUsO7ufsNk3X40-MYmelmwenDrTx3tcQP6I9d7XUV3qTgSNMQtxTpCciCtzDEB93R0X5mtJknj06w',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 333,
#   'title': '',
#   'profile_icon_id': 666,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 275,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9085,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'ofO-5uf2_QJkj1eqtwS2JOI8M3Lz4Kjoa_3Lgo_QNf-mQLpbL2QlYSXKZZv_cI1xVs0eiK7NJV7YWw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 315,
#   'title': '60200004',
#   'profile_icon_id': 4801,
#   'crest_border': '2',
#   'banner_accent': '16',
#   'prestige_crest_border_level': 0,
#   'total_points': {'level': 'GOLD',
#    'current': 6550,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'KwT9KYweUs1c4VVGhYHEurFB_1DmFsR5r7tONMlvxj8slm8tvVS268fYZzIJifBoCkZ85kjZ4iDGSw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 132,
#   'title': '51000603',
#   'profile_icon_id': 5125,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'SILVER',
#    'current': 2335,
#    'max': 29680,
#    'percentile': 0.335}},
#  {'puuid': 'F5DQ8UF3d5QF0DsE2h269AhrGQazzSVU974R_T481DdY9W_L93pmJLdbVkUmVzKIXbjqqsFTdw-45A',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 190,
#   'title': '',
#   'profile_icon_id': 984,
#   'crest_border': None,
#   'banner_accent': '',
#   'prestige_crest_border_level': None,
#   'total_points': {'level': 'GOLD',
#    'current': 5785,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'E82LoL2xmdwxCHrFuGDsbHwPicsiOF2ofIgdViStFEW_-BQv7wUIDO4a4NFE11cIhWLyzcdbs05Keg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 288,
#   'title': '',
#   'profile_icon_id': 4057,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 150,
#   'total_points': {'level': 'PLATINUM',
#    'current': 12460,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'aroAAD0h7PVGszMjkiC5m8gEXtvQFt9bCNzIMDdyfq-WzZKWpKX0UMEXHWIvij3hoZhvrhpMKwEKRg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 149,
#   'title': '',
#   'profile_icon_id': 6,
#   'crest_border': None,
#   'banner_accent': '',
#   'prestige_crest_border_level': None,
#   'total_points': {'level': 'GOLD',
#    'current': 6670,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'hzXYX2ADuxiLxQqJqkxbGBdQC6HX4To5lM0JtGbi9LPAEUezti9CgFEBT2TWniBFgjPkPIzLsFtg7Q',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 329,
#   'title': '40130204',
#   'profile_icon_id': 6006,
#   'crest_border': '1',
#   'banner_accent': '22',
#   'prestige_crest_border_level': 325,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9575,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'S4V0Z4p3hrdzedyNeCCkWwI09q2ZfDTD-u0pf6dYYlzurC4Fok9FHxsI82v-zRrQV_VGl9lfcsYO1A',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 246,
#   'title': '10120005',
#   'profile_icon_id': 786,
#   'crest_border': '2',
#   'banner_accent': '22',
#   'prestige_crest_border_level': 225,
#   'total_points': {'level': 'GOLD',
#    'current': 5985,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'EyqXpPBqSNCPl58Uf-nuLAlgoWDPKVS-ON8IWOpNzhHXzf_nvs83U8bp_LeCI08I84hTPsz9BjTrhA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 277,
#   'title': '',
#   'profile_icon_id': 5451,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 250,
#   'total_points': {'level': 'PLATINUM',
#    'current': 9230,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'A28yX-_iOjHC7WR2ih_DmsGrCt096zMJXQU1JWERx_8r5becb1KGhMNjfYDyrCimUZwzSZJOlgxAig',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 453,
#   'title': '30210203',
#   'profile_icon_id': 3182,
#   'crest_border': '1',
#   'banner_accent': '4',
#   'prestige_crest_border_level': 425,
#   'total_points': {'level': 'PLATINUM',
#    'current': 10980,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'M9JWvQbiAk781AtUGtkg6_jMjvKLSkrcAHe_FrfFKl4u63wp8yiTrEMouvKiioC1j6A_wi8mEOAl7Q',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 227,
#   'title': '60300007',
#   'profile_icon_id': 3494,
#   'crest_border': '1',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 175,
#   'total_points': {'level': 'GOLD',
#    'current': 6175,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'IMzhg212VRwJA46-YRgI3a9qbPk0C6zCCvaOewtOE50-NCd5EmbXA5vklVotbQ62q7qcxzrQ6fUvjw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 225,
#   'title': '60300705',
#   'profile_icon_id': 5959,
#   'crest_border': '2',
#   'banner_accent': '22',
#   'prestige_crest_border_level': 200,
#   'total_points': {'level': 'GOLD',
#    'current': 5285,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '5ocM6XciYOUxKEXO0KI4XYyfl89fsRDtfltYoqwwiaWRUjzCekTZ4n8lQDUMuvWWXjrEhwCgvVeCIA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 621,
#   'title': '40130604',
#   'profile_icon_id': 7028,
#   'crest_border': '2',
#   'banner_accent': '4',
#   'prestige_crest_border_level': 325,
#   'total_points': {'level': 'DIAMOND',
#    'current': 16440,
#    'max': 29680,
#    'percentile': 0.036}},
#  {'puuid': '7Pe6ITFP3WU5pRnGKcBc5HfrSUs4Mxt5l8TQnezAGyVudvPSmiIwbsN72qPedYWVvPt_QlWhm_rCtw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 101,
#   'title': '40130304',
#   'profile_icon_id': 539,
#   'crest_border': '2',
#   'banner_accent': '15',
#   'prestige_crest_border_level': 75,
#   'total_points': {'level': 'GOLD',
#    'current': 6505,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'kmf06V4ZTQqNPuIBaDT9OKka8wLcQsDpOanSrdM1uoR4QTA14O55X41d37M-Ef9OC_pYwQLaJ1mwUQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 389,
#   'title': '30210504',
#   'profile_icon_id': 4017,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 225,
#   'total_points': {'level': 'DIAMOND',
#    'current': 15000,
#    'max': 29680,
#    'percentile': 0.036}},
#  {'puuid': 'x3z3qWp45uJh8K83dwifVRJT86-QQN_g2dEVTsid_EIP2asGzPQgXH02cFrz3VFhGJuXCAUdsFXicQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 175,
#   'title': '40130104',
#   'profile_icon_id': 654,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 100,
#   'total_points': {'level': 'PLATINUM',
#    'current': 10365,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'JJ0f5BHmB_M7bcpFWn8flUw4vTJVDZBTNS8y40fH35sNl-IcdY5DGasU32rmUz6yeO8k0mpF96fe2w',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 840,
#   'title': '40130404',
#   'profile_icon_id': 3901,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 500,
#   'total_points': {'level': 'DIAMOND',
#    'current': 18850,
#    'max': 29680,
#    'percentile': 0.036}},
#  {'puuid': 'Ha3aLPqfaCEhRSzSkNCg1qNlmUYcVsgnzYx-U3ZxeYSnWDkulVCXBHdkyRNUm1zmAs2nj2ba7ZvgLg',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 78,
#   'title': '30110203',
#   'profile_icon_id': 1159,
#   'crest_border': '2',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 50,
#   'total_points': {'level': 'GOLD',
#    'current': 5780,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': '74wt5Aab6dOojYlqHXQkqWzIvPL5GZihIuHvXoM7aaIOq0tLPjtpdQptkSr_FcsSWr_VPLc07PqJ4g',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 289,
#   'title': '40210604',
#   'profile_icon_id': 715,
#   'crest_border': '2',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 225,
#   'total_points': {'level': 'DIAMOND',
#    'current': 14655,
#    'max': 29680,
#    'percentile': 0.036}},
#  {'puuid': 'dkLMSCoheFPEt9o9dLUJFtQJOwqgy0hr9wt4QeEh5GmSEdW6TsUK5y2t2HDeOXZ41R0IfuKC315hSA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 640,
#   'title': '51000006',
#   'profile_icon_id': 550,
#   'crest_border': '1',
#   'banner_accent': '6',
#   'prestige_crest_border_level': 450,
#   'total_points': {'level': 'PLATINUM',
#    'current': 13775,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': '2pONV1flLAF06O_E4-TR7WwyDYJshRV7tOSdJ6-wCC6VHzhORkh_-PwgwU3WYG-4mtwhUMbBCx6NcA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 318,
#   'title': '',
#   'profile_icon_id': 1627,
#   'crest_border': '2',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 250,
#   'total_points': {'level': 'GOLD',
#    'current': 8385,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'CR2UXEnvF8avTkso6lpARkHaWNk7tyOuadPvmtYsWt8VxumbK2VB4KQ5wkuVcPwcM6UbCHCpCFgE3A',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 273,
#   'title': '40210604',
#   'profile_icon_id': 1636,
#   'crest_border': '1',
#   'banner_accent': '22',
#   'prestige_crest_border_level': 250,
#   'total_points': {'level': 'PLATINUM',
#    'current': 11545,
#    'max': 29680,
#    'percentile': 0.101}},
#  {'puuid': 'qWPEJNrCYItKkepQPjiXO2V9WaWTulMW05RK5odcpSbEwjOTVEASbGrgk0D2LdlMJ0cbHsxIZGx_HQ',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 178,
#   'title': '30210504',
#   'profile_icon_id': 8,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 30,
#   'total_points': {'level': 'GOLD',
#    'current': 8385,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'dK_y9AL6NXMW3uGQ3DmN_1Bi3RY4tz_bDOUxxPDkWt_y9LdWWbQanc_EqxbMxv1BifgDvRAvw3K9MA',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 197,
#   'title': '',
#   'profile_icon_id': 4652,
#   'crest_border': '1',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 175,
#   'total_points': {'level': 'GOLD',
#    'current': 5655,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'E07CP4DFDAsOQYM_RETBJ1tRISp2gWp9E-UMpwYenOS5et5DD75ojfRpldwAfvQLhPbZZyCoRSSpuw',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 205,
#   'title': '',
#   'profile_icon_id': 5212,
#   'crest_border': '1',
#   'banner_accent': '',
#   'prestige_crest_border_level': 150,
#   'total_points': {'level': 'GOLD',
#    'current': 6815,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'W4Ab13lZk15IH3i1EJoCoFtNYbmH7y3HLRjkgU_LL7CJ7RU0c6PIi3b6gw-aNZ1agPxjcplJva6t1g',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 162,
#   'title': '51000603',
#   'profile_icon_id': 589,
#   'crest_border': '2',
#   'banner_accent': '2',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'GOLD',
#    'current': 5190,
#    'max': 29680,
#    'percentile': 0.203}},
#  {'puuid': 'FzHQmRkXjVBJAwx7kigmPifwiQ8IM-VpQgDrbEBrXG4S7K0XnKVjtRwybX55p39JX3Dm0IRuPpPR8A',
#   'snapshot_date': datetime.date(2026, 6, 2),
#   'summoner_level': 170,
#   'title': '20310302',
#   'profile_icon_id': 513,
#   'crest_border': '2',
#   'banner_accent': '1',
#   'prestige_crest_border_level': 125,
#   'total_points': {'level': 'GOLD',
#    'current': 6400,
#    'max': 29680,
#    'percentile': 0.203}},
#  ...]

# %%
player_snapshot_df=pl.DataFrame(player_snapshot_arr)
player_snapshot_df
# Out:
# shape: (3_100, 9)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ puuid     ┆ snapshot_ ┆ summoner_ ┆ title    ┆ … ┆ crest_bor ┆ banner_ac ┆ prestige_ ┆ total_poi │
# │ ---       ┆ date      ┆ level     ┆ ---      ┆   ┆ der       ┆ cent      ┆ crest_bor ┆ nts       │
# │ str       ┆ ---       ┆ ---       ┆ str      ┆   ┆ ---       ┆ ---       ┆ der_level ┆ ---       │
# │           ┆ date      ┆ i64       ┆          ┆   ┆ str       ┆ str       ┆ ---       ┆ struct[4] │
# │           ┆           ┆           ┆          ┆   ┆           ┆           ┆ i64       ┆           │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ x1jqYLksF ┆ 2026-06-0 ┆ 158       ┆ 10320704 ┆ … ┆ 1         ┆           ┆ 150       ┆ {"SILVER" │
# │ HSjj-V_dT ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ ,3365,296 │
# │ eZrzR9fFE ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 80,0.335} │
# │ VDt…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# │ QMPPN4oUr ┆ 2026-06-0 ┆ 84        ┆ 1420     ┆ … ┆ 1         ┆ 2         ┆ 75        ┆ {"GOLD",4 │
# │ Y-FW-BBOZ ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ 595,29680 │
# │ 34yDZZmjg ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ ,0.203}   │
# │ hPa…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# │ yf1OVyzGt ┆ 2026-06-0 ┆ 32        ┆ 1        ┆ … ┆ 1         ┆ 1         ┆ 30        ┆ {"BRONZE" │
# │ KFWKAh__N ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ ,1485,296 │
# │ IUFtnEisd ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 80,0.434} │
# │ ohM…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# │ gw0udTm33 ┆ 2026-06-0 ┆ 108       ┆ 40240802 ┆ … ┆ 1         ┆ 1         ┆ 75        ┆ {"GOLD",4 │
# │ m9cDPfENX ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ 625,29680 │
# │ ndpjlXmkH ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ ,0.203}   │
# │ wxl…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# │ tD8QYcsn9 ┆ 2026-06-0 ┆ 143       ┆ 40130204 ┆ … ┆ 1         ┆           ┆ 100       ┆ {"GOLD",8 │
# │ jmPaM7AAC ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ 455,29680 │
# │ N9Id2fwgu ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ ,0.203}   │
# │ sfN…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …         ┆ …         ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ dYiEC-rav ┆ 2026-06-0 ┆ 126       ┆          ┆ … ┆ 2         ┆ 1         ┆ 75        ┆ {"PLATINU │
# │ Kg74XNQMp ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ M",11030, │
# │ 4KsOp4S7a ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 29680,0.1 │
# │ VlR…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 01}       │
# │ ZLw_1J27y ┆ 2026-06-0 ┆ 1101      ┆          ┆ … ┆ 1         ┆ 8         ┆ 0         ┆ {"DIAMOND │
# │ iyrFC_UN7 ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ ",19015,2 │
# │ -Uck-IyYM ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 9680,0.03 │
# │ BLL…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 6}        │
# │ 0CPr6RzHV ┆ 2026-06-0 ┆ 968       ┆          ┆ … ┆ 2         ┆ 15        ┆ 0         ┆ {"DIAMOND │
# │ it2UWf0Cu ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ ",20570,2 │
# │ 0EXPbIj77 ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 9680,0.03 │
# │ eko…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 6}        │
# │ voxGacYDh ┆ 2026-06-0 ┆ 570       ┆ 20200006 ┆ … ┆ 1         ┆ 2         ┆ 0         ┆ {"DIAMOND │
# │ Q3ptNab4t ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ ",18925,2 │
# │ Ge6ipPP3n ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 9680,0.03 │
# │ Zfc…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 6}        │
# │ eMwumb2gC ┆ 2026-06-0 ┆ 83        ┆ 10110403 ┆ … ┆ 1         ┆ 1         ┆ 30        ┆ {"PLATINU │
# │ UrYSrSf3D ┆ 2         ┆           ┆          ┆   ┆           ┆           ┆           ┆ M",9000,2 │
# │ 1t_9CyIv3 ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 9680,0.10 │
# │ kPH…      ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆ 1}        │
# └───────────┴───────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import json

(player_snapshot_df
.with_columns(pl.col("total_points").map_elements(json.dumps).alias("total_points"))
.with_columns(pl.col(pl.Int64).cast(pl.Int32),pl.col(pl.Float64).cast(pl.Float32))
.write_database(
    table_name="player_snapshots",
    connection=POSTGRES_LOCAL_URL,
    if_table_exists="append",
    engine="adbc"
))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[16], line 6
#       2
#       3 (player_snapshot_df
#       4 .with_columns(pl.col("total_points").map_elements(json.dumps).alias("total_points"))
#       5 .with_columns(pl.col(pl.Int64).cast(pl.Int32),pl.col(pl.Float64).cast(pl.Float32))
# ----> 6 .write_database(
#       7     table_name="player_snapshots",
#       8     connection=POSTGRES_LOCAL_URL,
#       9     if_table_exists="append",
#
# File ~/foresight-lol/.venv/lib/python3.14/site-packages/polars/dataframe/frame.py:4616, in DataFrame.write_database(self, table_name, connection, if_table_exists, engine, engine_options)
#    4612                 # use of schema-qualified table names was released in
#    4613                 # adbc-driver-manager 0.7.0 and is working without bugs from driver
#    4614                 # version (e.g., adbc-driver-postgresql) version 0.8.0
#    4615                 if driver_manager_version >= (0, 7) and adbc_driver_version >= (0, 8):
# -> 4616                     n_rows = cursor.adbc_ingest(
#    4617                         unpacked_table_name,
#    4618                         data=data,
#    4619                         mode=mode,
#
# File ~/foresight-lol/.venv/lib/python3.14/site-packages/adbc_driver_manager/dbapi.py:1200, in Cursor.adbc_ingest(self, table_name, data, mode, catalog_name, db_schema_name, temporary)
#    1197     raise TypeError(f"Cannot bind {type(data)}")
#    1199 self._last_query = None
# -> 1200 return _blocking_call(self._stmt.execute_update, (), {}, self._stmt.cancel)
#
# File adbc_driver_manager/_lib.pyx:1956, in adbc_driver_manager._lib._blocking_call_impl()
# -> 1956 'Could not get source, probably due dynamically evaluated source code.'
#
# File adbc_driver_manager/_lib.pyx:1949, in adbc_driver_manager._lib._blocking_call_impl()
# -> 1949 'Could not get source, probably due dynamically evaluated source code.'
#
# File adbc_driver_manager/_lib.pyx:1653, in adbc_driver_manager._lib.AdbcStatement.execute_update()
# -> 1653 'Could not get source, probably due dynamically evaluated source code.'
#
# File adbc_driver_manager/_lib.pyx:262, in adbc_driver_manager._lib.check_error()
# --> 262 'Could not get source, probably due dynamically evaluated source code.'
#
# ProgrammingError: INVALID_ARGUMENT: [libpq] Failed to execute COPY statement: PGRES_FATAL_ERROR ERROR:  wrong number of columns: 2065853541, expected 4
# CONTEXT:  COPY player_snapshots, line 1, column total_points
# . SQLSTATE: 42804

# %%
from utils.postgres.postgres_connection import PostgresConnection
connection_wrapper = PostgresConnection(POSTGRES_LOCAL_URL)
# Out:
# opening connection

# %%
connection_wrapper.upsert_dataframe_dto_safe(player_snapshot_df, "player_snapshots", ["puuid", "snapshot_date"])
# Out:
# 0
